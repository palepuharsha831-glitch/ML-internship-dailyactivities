# %%
l=[]
print(l)
print(type(l))
# Out:
# []
# <class 'list'>

# %%
l=[1,2,3,4,5,6]
print(l)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l.append(7)
print(l)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
l.insert(1,8)
print(l)
# Out:
# [1, 8, 2, 3, 4, 5, 6, 7]

# %%
l.pop()
print(l)
# Out:
# [1, 8, 2, 3, 4, 5, 6]

# %%
l.pop(1)
print(l)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l.remove(5)
print(l)
# Out:
# [1, 2, 3, 4, 6]

# %%
l1=[1,2,3]
l2=[4,5,6]
l1.append(l2)
print(l1)
# Out:
# [1, 2, 3, [4, 5, 6]]

# %%
l1=[1,2,3]
l2=[4,5,6]
l1.extend(l2)
print(l1)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
print(l1)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l.clear()
print(l)
# Out:
# []

# %%
del l

# %%
print(l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 print(l)
#
# NameError: name 'l' is not defined

# %%
l=[1,5,6,8,2,8,9]
l.sort()
print(l)
# Out:
# [1, 2, 5, 6, 8, 8, 9]

# %%
l=[1,5,6,8,2,8,9]
print(sorted(l))
# Out:
# [1, 2, 5, 6, 8, 8, 9]

# %%
l=[1,5,6,8,2,8,9]
l.reverse()
print(l)
# Out:
# [9, 8, 2, 8, 6, 5, 1]

# %% [markdown]
# Dictionary

# %%
d={}
print(d)
print(type(d))
# Out:
# {}
# <class 'dict'>

# %%
d={"name":"harsha","city":"kakinada"}
print(d)
# Out:
# {'name': 'harsha', 'city': 'kakinada'}

# %%
print(d["name"])
# Out:
# harsha

# %%
d["mobile_number"]=6301840427
print(d)
# Out:
# {'name': 'harsha', 'city': 'kakinada', 'mobile_number': 6301840427}

# %%
d["city"]="hyd"
print(d)
# Out:
# {'name': 'harsha', 'city': 'hyd', 'mobile_number': 6301840427}

# %%
print(d.keys())
# Out:
# dict_keys(['name', 'city', 'mobile_number'])

# %%
print(d.values())
# Out:
# dict_values(['harsha', 'hyd', 6301840427])

# %%
print(d.items())
# Out:
# dict_items([('name', 'harsha'), ('city', 'hyd'), ('mobile_number', 6301840427)])

# %%
f=open('anc.txt','w')
print('File name:',f.name)
print('File mode:',f.mode)
print(f.readable())
print(f.writable())
print(f.closed)
f.close()
print(f.closed)
# Out:
# File name: anc.txt
# File mode: w
# False
# True
# False
# True

# %%
with open("anc.txt","r") as file:
    content = file.read()
print(content)
# Out:
# aditya degree college

# %%
with open("anc.txt","r") as file:
    content = file.read(10)
print(content)
# Out:
# aditya deg

# %%
with open("anc.txt","r") as file:
    content = file.readline()
print(content)
# Out:
# aditya degree college

# %%
with open("anc.txt","r") as file:
    content = file.readlines()
print(content)
# Out:
# ['aditya degree college ']

# %%
with open("anc.txt","w") as file:
    file.write("Aditya Degree college")

# %%
l=["Aditya Degree college\n","kakinada\n","Andhra pradesh\n"]
with open("anc.txt","w") as file:
    file.writelines(l)

# %%
with open("anc.txt","a") as file:
    file.write("533003")
