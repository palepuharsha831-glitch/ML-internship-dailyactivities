# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
 data = {
    "Study_Hours": [1,2,3,4,5,],
    "Marks":      [10,25,55,90,130]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#    Study_Hours  Marks
# 0            1     10
# 1            2     25
# 2            3     55
# 3            4     90
# 4            5    130

# %%
X = df[["Study_Hours"]]
y = df["Marks"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.4, random_state=42)

# %%
X_train
# Out:
#    Study_Hours
# 2            3
# 0            1
# 3            4

# %%
poly = PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(X_train)
x_test_poly = poly.transform(X_test)

# %%
model = LinearRegression()
model.fit(X_train_poly, y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = model.predict(X_train_poly)
y_test_pred = model.predict(x_test_poly)

# %%
print("Training MSE:",mean_squared_error(y_train, y_train_pred))
print("Testing MSE:",mean_squared_error(y_test, y_test_pred))
# Out:
# Training MSE: 2.3560645702600887e-28
# Testing MSE: 11.111111111110914

# %%
plt.scatter(X,y, color='blue', label='Actual Data')
X_line = np.linspace(min(X['Study_Hours']), max(X['Study_Hours']), 100).reshape(-1, 1)
y_line = model.predict(poly.transform(X_line))
plt.plot(X_line, y_line, color='red', label='Polynomial Fit')
plt.Xlabel('Study Hours')
plt.ylabel('Marks')
plt.title('Polynomial Regression Example')
plt.legend()
plt.show()
# Out:
# C:\Users\HARSHAVARDINI\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 5
#       3 y_line = model.predict(poly.transform(X_line))
#       4 plt.plot(X_line, y_line, color='red', label='Polynomial Fit')
# ----> 5 plt.Xlabel('Study Hours')
#       6 plt.ylabel('Marks')
#       7 plt.title('Polynomial Regression Example')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'Xlabel'

# %%
b0 = model.intercept_
b1 = model.coef_[1]
b2 = model.coef_[2]


print("b0 =", b0)
print("b1 =", b1)
print("b2 =", b2)
# Out:
# b0 = 1.4210854715202004e-14
# b1 = 5.8333333333333455
# b2 = 4.166666666666662

# %%
X_new = pd.DataFrame({'Study_Hours': [6.0]})
X_new_poly = poly.transform(X_new)
y_new = model.predict(X_new_poly)
print("Predicated , Value:", y_new)
# Out:
# Predicated , Value: [185.]
