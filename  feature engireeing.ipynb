# %% [markdown]
# # FEATURE CREATION

# %%
import pandas as pd

df = pd.DataFrame({
    "Study_Hours":[2,4,6,8,10],
    "Attendence":[60,70,80,90,95],
    "Maths":[40,55,65,75,80],
    "Science":[42,58,68,78,88]

})

# %%
df
# Out:
#    Study_Hours  Attendence  Maths  Science
# 0            2          60     40       42
# 1            4          70     55       58
# 2            6          80     65       68
# 3            8          90     75       78
# 4           10          95     80       88

# %% [markdown]
# # Domain-Based feature

# %%
df["Total_Marks"] = df["Maths"] + df["Science"]
df
# Out:
#    Study_Hours  Attendence  Maths  Science  Total_Marks
# 0            2          60     40       42           82
# 1            4          70     55       58          113
# 2            6          80     65       68          133
# 3            8          90     75       78          153
# 4           10          95     80       88          168

# %% [markdown]
# # Mathematical Feature

# %%
df["Marks_per_Hour"] = df["Total_Marks"] / df["Study_Hours"]

# %%
df
# Out:
#    Study_Hours  Attendence  Maths  Science  Total_Marks  Marks_per_Hour
# 0            2          60     40       42           82       41.000000
# 1            4          70     55       58          113       28.250000
# 2            6          80     65       68          133       22.166667
# 3            8          90     75       78          153       19.125000
# 4           10          95     80       88          168       16.800000

# %% [markdown]
# # Interaction feature

# %%
df["Study_Attandence_Interaction"] = df["Study_Hours"] * df["Attendence"]

# %%
df
# Out:
#    Study_Hours  Attendence  Maths  Science  Total_Marks  Marks_per_Hour  \
# 0            2          60     40       42           82       41.000000
# 1            4          70     55       58          113       28.250000
# 2            6          80     65       68          133       22.166667
# 3            8          90     75       78          153       19.125000
# 4           10          95     80       88          168       16.800000
#
#    Study_Attandence_Interaction
# 0                           120
# 1                           280
# 2                           480
# 3                           720
# 4                           950

# %% [markdown]
# # polynomial Feaure

# %%
df["Study_Hours_Squared"] = df["Study_Hours"] **2

# %%
df
# Out:
#    Study_Hours  Attendence  Maths  Science  Total_Marks  Marks_per_Hour  \
# 0            2          60     40       42           82       41.000000
# 1            4          70     55       58          113       28.250000
# 2            6          80     65       68          133       22.166667
# 3            8          90     75       78          153       19.125000
# 4           10          95     80       88          168       16.800000
#
#    Study_Attandence_Interaction  Study_Hours_Squared
# 0                           120                    4
# 1                           280                   16
# 2                           480                   36
# 3                           720                   64
# 4                           950                  100

# %% [markdown]
# # feature selection

# %%
df
# Out:
#    Study_Hours  Attendence  Maths  Science  Total_Marks  Marks_per_Hour  \
# 0            2          60     40       42           82       41.000000
# 1            4          70     55       58          113       28.250000
# 2            6          80     65       68          133       22.166667
# 3            8          90     75       78          153       19.125000
# 4           10          95     80       88          168       16.800000
#
#    Study_Attandence_Interaction  Study_Hours_Squared
# 0                           120                    4
# 1                           280                   16
# 2                           480                   36
# 3                           720                   64
# 4                           950                  100

# %%
x = df.drop("Science",axis=1)
y = df["Science"]

# %%
x
# Out:
#    Study_Hours  Attendence  Maths  Total_Marks  Marks_per_Hour  \
# 0            2          60     40           82       41.000000
# 1            4          70     55          113       28.250000
# 2            6          80     65          133       22.166667
# 3            8          90     75          153       19.125000
# 4           10          95     80          168       16.800000
#
#    Study_Attandence_Interaction  Study_Hours_Squared
# 0                           120                    4
# 1                           280                   16
# 2                           480                   36
# 3                           720                   64
# 4                           950                  100

# %%
y
# Out:
# 0    42
# 1    58
# 2    68
# 3    78
# 4    88
# Name: Science, dtype: int64

# %% [markdown]
# #filter methods(statistics-based)
#
# # correlation method

# %%
df.corr()["Science"].sort_values(ascending=False)
# Out:
# Science                         1.000000
# Total_Marks                     0.998981
# Maths                           0.995467
# Study_Hours                     0.994309
# Attendence                      0.994110
# Study_Attandence_Interaction    0.983804
# Study_Hours_Squared             0.958102
# Marks_per_Hour                 -0.968737
# Name: Science, dtype: float64

# %% [markdown]
# # selecting important featuress

# %%
corr = df.corr()["Science"].abs()

# %%
corr
# Out:
# Study_Hours                     0.994309
# Attendence                      0.994110
# Maths                           0.995467
# Science                         1.000000
# Total_Marks                     0.998981
# Marks_per_Hour                  0.968737
# Study_Attandence_Interaction    0.983804
# Study_Hours_Squared             0.958102
# Name: Science, dtype: float64

# %%
selected_features = corr[corr > 0.8].index
selected_features
# Out:
# Index(['Study_Hours', 'Attendence', 'Maths', 'Science', 'Total_Marks',
#        'Marks_per_Hour', 'Study_Attandence_Interaction',
#        'Study_Hours_Squared'],
#       dtype='object')
